# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import os
import pathlib
import random as rn
from sklearn.model_selection import train_test_split
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from sklearn.metrics import accuracy_score

# %%
import zipfile

# %%
# Dataset Link: https://www.kaggle.com/datasets/meowmeowmeowmeowmeow/gtsrb-german-traffic-sign

# %%
zip_file = "archive.zip"
 
try:
    with zipfile.ZipFile(zip_file) as z:
        z.extractall()
        print("Extracted all")
except:
    print("Invalid file")
# Out:
# Extracted all

# %%
 
train_path = r"./Train/"
test_path = r"./"
height = 50
width = 50

# %% [markdown]
# # Declaring labels for each sample

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
batch_size = 150
seed = 42

# %% [markdown]
# # Scaling and Preprocessing the Image Data

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   validation_split=0.2)
train_dataset = train_datagen.flow_from_directory(train_path,
                                                  target_size=(height, width),
                                                  batch_size=batch_size,
                                                  class_mode='categorical',
                                                  shuffle=True,
                                                  seed=seed,
                                                  color_mode='rgb',
                                                  interpolation='hamming',
                                                  subset='training')

test_datagen = ImageDataGenerator(rescale=1./255,
                                  validation_split=0.2)
test_dataset = test_datagen.flow_from_directory(train_path,
                                                target_size=(height, width),
                                                batch_size=batch_size,
                                                class_mode='categorical',
                                                shuffle=True,
                                                seed=seed,
                                                color_mode='rgb',
                                                interpolation='hamming',
                                                subset='validation')
# Out:
# Found 31368 images belonging to 43 classes.
# Found 7841 images belonging to 43 classes.

# %% [markdown]
# # Plotting the Images along with Labels

# %%
fig,ax=plt.subplots(3,4)
fig.set_size_inches(16,12)
img,y = train_dataset.next()
for i in range(3):
    for j in range (4):
        l=rn.randint(0,batch_size-1)
        label = classes[int(list(train_dataset.class_indices.keys())[np.argmax(y[l])])]
        ax[i,j].imshow(img[l])
        ax[i,j].set_title(label)

plt.tight_layout()

# %% [markdown]
# # Training the Convolutional Neural Network

# %%
model = keras.models.Sequential([    
    keras.layers.Conv2D(filters=16, kernel_size=(5,5), activation='relu', input_shape=(height,width,3)),
    keras.layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),
    keras.layers.Dropout(rate=0.25),
    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(rate=0.25),
    
    keras.layers.Dense(43, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 16)        1216
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 32)        12832
#
#  max_pooling2d (MaxPooling2  (None, 21, 21, 32)        0
#  D)
#
#  batch_normalization (Batch  (None, 21, 21, 32)        128
#  Normalization)
#
#  conv2d_2 (Conv2D)           (None, 19, 19, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 17, 17, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  batch_normalization_1 (Bat  (None, 8, 8, 64)          256
#  chNormalization)
#
#  dropout (Dropout)           (None, 8, 8, 64)          0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  batch_normalization_2 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 43)                22059
#
# =================================================================
# Total params: 2191627 (8.36 MB)
# Trainable params: 2190411 (8.36 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________

# %%
alpha=0.01
epochs=5
optim = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer = optim, loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(train_dataset,
                    steps_per_epoch=len(train_dataset),
                    epochs=epochs,
                    validation_data=test_dataset,
                    validation_steps=len(test_dataset))
# Out:
# Epoch 1/5
# 210/210 [==============================] - 142s 666ms/step - loss: 0.6451 - accuracy: 0.8287 - val_loss: 0.3883 - val_accuracy: 0.9037
# Epoch 2/5
# 210/210 [==============================] - 144s 684ms/step - loss: 0.0685 - accuracy: 0.9805 - val_loss: 0.3022 - val_accuracy: 0.9222
# Epoch 3/5
# 210/210 [==============================] - 142s 675ms/step - loss: 0.0481 - accuracy: 0.9849 - val_loss: 0.3113 - val_accuracy: 0.9361
# Epoch 4/5
# 210/210 [==============================] - 131s 621ms/step - loss: 0.0423 - accuracy: 0.9872 - val_loss: 0.3628 - val_accuracy: 0.9304
# Epoch 5/5
# 210/210 [==============================] - 139s 662ms/step - loss: 0.0296 - accuracy: 0.9905 - val_loss: 0.4253 - val_accuracy: 0.9186

# %% [markdown]
# # Plotting the Accuracy and Loss of train and test data

# %%
fig,ax=plt.subplots(1,2)
fig.set_size_inches(16,12)
performance = pd.DataFrame(history.history)
plt.figure(figsize=(10,7))
ax[1].plot(performance[['loss','val_loss']])
ax[1].legend(['Training Loss', 'Validation Loss'])
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_ylim(0,1)
ax[0].plot(performance[['accuracy','val_accuracy']])
ax[0].legend(['Training Accuracy', 'Validation Accuracy'])
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].set_ylim(0.5,1)
fig.suptitle('Custom CNN Performance')
plt.show()

# %%
model.save("CNN.h5")
# Out:
# /home/zaeemtauqir/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Preparing the Test Data

# %%
def map_pred(pred):
    return [int(list(train_dataset.class_indices.keys())[i]) for i in pred]

test_df = pd.read_csv('./Test.csv')

test_labels = test_df["ClassId"].values
imgs = test_df["Path"].values

data =[]

for img in imgs:
    try:
        image = cv2.imread(test_path +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((height, width))
        data.append(np.array(resize_image))
    except:
        print("Error in " + img)

        
X_test = np.array(data)
X_test = X_test/255

# %% [markdown]
# # Predicting values for the Test Data

# %%
from sklearn.metrics import accuracy_score
pred = model.predict(X_test)
pred = map_pred(pred.argmax(axis=-1))
print('Test Data accuracy: ',accuracy_score(test_labels, pred)*100)
# Out:
# 2023-12-26 21:04:36.422772: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 378900000 exceeds 10% of free system memory.
# 395/395 [==============================] - 12s 29ms/step
# Test Data accuracy:  70.90261282660333

# %%
fig,ax=plt.subplots(3,4)
fig.set_size_inches(16,12)
val_images, val_labels = test_dataset.next()
predicted = model.predict(val_images)
predicts = map_pred(np.argmax(predicted, axis=-1))
labels = map_pred(np.argmax(val_labels, axis=-1))

for i in range(3):
    for j in range (4):
        idx=rn.randint(0,batch_size-1)
        ax[i,j].imshow(val_images[idx])
        if labels[idx] == predicts[idx]:
            ax[i,j].set_title('Actual: '+classes[labels[idx]]+'  \nPredicted: '+classes[predicts[idx]], color = 'green')
        else: 
            ax[i,j].set_title('Actual: '+classes[labels[idx]]+'  \nPredicted: '+classes[predicts[idx]], color = 'red')

plt.tight_layout()
# Out:
# 5/5 [==============================] - 0s 31ms/step

# %% [markdown]
# # Comparing Actual and Predicted Values for the Test data

# %%
true_count=0
false_count=0

# %%
for i in range(0,len(pred)):
    print(i+1 ," : Actual Value ",classes[test_labels[i]])
    print("Predicted Value ",classes[pred[i]])
    if classes[test_labels[i]]==classes[pred[i]]:
        true_count += 1
        print("True Prediction \n")
    else:
        false_count+= 1
        print("Wrong Prediction \n")
# Out:
# 1  : Actual Value  Veh > 3.5 tons prohibited
# Predicted Value  Veh > 3.5 tons prohibited
# True Prediction
#
# 2  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 3  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 4  : Actual Value  Turn right ahead
# Predicted Value  No entry
# Wrong Prediction
#
# 5  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 6  : Actual Value  Keep right
# Predicted Value  Stop
# Wrong Prediction
#
# 7  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 8  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 9  : Actual Value  Road work
# Predicted Value  Ahead only
# Wrong Prediction
#
# 10  : Actual Value  Ahead only
# Predicted Value  Yield
# Wrong Prediction
#
# 11  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 12  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 13  : Actual Value  Slippery road
# Predicted Value  Slippery road
# True Prediction
#
# 14  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 15  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 16  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 17  : Actual Value  Double curve
# Predicted Value  Dangerous curve left
# Wrong Prediction
#
# 18  : Actual Value  Dangerous curve right
# Predicted Value  Ahead only
# Wrong Prediction
#
# 19  : Actual Value  Pedestrians
# Predicted Value  Pedestrians
# True Prediction
#
# 20  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 21  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 22  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 23  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 24  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 25  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 26  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 27  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 28  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 29  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 30  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 31  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 32  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 33  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 34  : Actual Value  Slippery road
# Predicted Value  Slippery road
# True Prediction
#
# 35  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 36  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 37  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 38  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 39  : Actual Value  Veh > 3.5 tons prohibited
# Predicted Value  Veh > 3.5 tons prohibited
# True Prediction
#
# 40  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 41  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 42  : Actual Value  Beware of ice/snow
# Predicted Value  Beware of ice/snow
# True Prediction
#
# 43  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 44  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 45  : Actual Value  Road narrows on the right
# Predicted Value  Road narrows on the right
# True Prediction
#
# 46  : Actual Value  Road work
# Predicted Value  Keep right
# Wrong Prediction
#
# 47  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 48  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 49  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 50  : Actual Value  Speed limit (120km/h)
# Predicted Value  Stop
# Wrong Prediction
#
# 51  : Actual Value  Road work
# Predicted Value  Wild animals crossing
# Wrong Prediction
#
# 52  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 53  : Actual Value  No vehicles
# Predicted Value  No vehicles
# True Prediction
#
# 54  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 55  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 56  : Actual Value  Ahead only
# Predicted Value  Ahead only
# True Prediction
#
# 57  : Actual Value  Speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# Wrong Prediction
#
# 58  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 59  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 60  : Actual Value  Veh > 3.5 tons prohibited
# Predicted Value  Veh > 3.5 tons prohibited
# True Prediction
#
# 61  : Actual Value  Keep right
# Predicted Value  Stop
# Wrong Prediction
#
# 62  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 63  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 64  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 65  : Actual Value  No vehicles
# Predicted Value  No vehicles
# True Prediction
#
# 66  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 67  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 68  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 69  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 70  : Actual Value  Children crossing
# Predicted Value  Children crossing
# True Prediction
#
# 71  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 72  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 73  : Actual Value  Beware of ice/snow
# Predicted Value  Beware of ice/snow
# True Prediction
#
# 74  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 75  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 76  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 77  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 78  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 79  : Actual Value  Road work
# Predicted Value  Keep right
# Wrong Prediction
#
# 80  : Actual Value  Road work
# Predicted Value  Keep right
# Wrong Prediction
#
# 81  : Actual Value  Double curve
# Predicted Value  Double curve
# True Prediction
#
# 82  : Actual Value  Turn right ahead
# Predicted Value  Turn right ahead
# True Prediction
#
# 83  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 84  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 85  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 86  : Actual Value  Ahead only
# Predicted Value  Stop
# Wrong Prediction
#
# 87  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 88  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 89  : Actual Value  Bumpy road
# Predicted Value  Bumpy road
# True Prediction
#
# 90  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 91  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 92  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 93  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 94  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 95  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 96  : Actual Value  End speed + passing limits
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 97  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 98  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 99  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 100  : Actual Value  Turn right ahead
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 101  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 102  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 103  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (50km/h)
# Wrong Prediction
#
# 104  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 105  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 106  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 107  : Actual Value  Ahead only
# Predicted Value  Stop
# Wrong Prediction
#
# 108  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 109  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 110  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 111  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 112  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 113  : Actual Value  Veh > 3.5 tons prohibited
# Predicted Value  Veh > 3.5 tons prohibited
# True Prediction
#
# 114  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 115  : Actual Value  Beware of ice/snow
# Predicted Value  Beware of ice/snow
# True Prediction
#
# 116  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 117  : Actual Value  Pedestrians
# Predicted Value  Pedestrians
# True Prediction
#
# 118  : Actual Value  Bicycles crossing
# Predicted Value  Slippery road
# Wrong Prediction
#
# 119  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 120  : Actual Value  No entry
# Predicted Value  Keep left
# Wrong Prediction
#
# 121  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 122  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 123  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 124  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 125  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 126  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 127  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 128  : Actual Value  Beware of ice/snow
# Predicted Value  Beware of ice/snow
# True Prediction
#
# 129  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 130  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 131  : Actual Value  Go straight or right
# Predicted Value  Go straight or right
# True Prediction
#
# 132  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 133  : Actual Value  Stop
# Predicted Value  Keep right
# Wrong Prediction
#
# 134  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 135  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 136  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 137  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 138  : Actual Value  Roundabout mandatory
# Predicted Value  Stop
# Wrong Prediction
#
# 139  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 140  : Actual Value  Keep right
# Predicted Value  Road work
# Wrong Prediction
#
# 141  : Actual Value  End of no passing
# Predicted Value  End of no passing
# True Prediction
#
# 142  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 143  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 144  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 145  : Actual Value  No entry
# Predicted Value  Keep right
# Wrong Prediction
#
# 146  : Actual Value  Road work
# Predicted Value  Wild animals crossing
# Wrong Prediction
#
# 147  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 148  : Actual Value  End of no passing
# Predicted Value  End of no passing
# True Prediction
#
# 149  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 150  : Actual Value  Double curve
# Predicted Value  Double curve
# True Prediction
#
# 151  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 152  : Actual Value  Road narrows on the right
# Predicted Value  Road narrows on the right
# True Prediction
#
# 153  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 154  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 155  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 156  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 157  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 158  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 159  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 160  : Actual Value  Speed limit (70km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 161  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 162  : Actual Value  Veh > 3.5 tons prohibited
# Predicted Value  Veh > 3.5 tons prohibited
# True Prediction
#
# 163  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 164  : Actual Value  Road work
# Predicted Value  Traffic signals
# Wrong Prediction
#
# 165  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 166  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 167  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 168  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 169  : Actual Value  Bicycles crossing
# Predicted Value  Slippery road
# Wrong Prediction
#
# 170  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 171  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 172  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 173  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 174  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 175  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 176  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 177  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 178  : Actual Value  Roundabout mandatory
# Predicted Value  Stop
# Wrong Prediction
#
# 179  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 180  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 181  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 182  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (100km/h)
# Wrong Prediction
#
# 183  : Actual Value  Go straight or right
# Predicted Value  Go straight or right
# True Prediction
#
# 184  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 185  : Actual Value  Dangerous curve right
# Predicted Value  Dangerous curve right
# True Prediction
#
# 186  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 187  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 188  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 189  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 190  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 191  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 192  : Actual Value  Bicycles crossing
# Predicted Value  Slippery road
# Wrong Prediction
#
# 193  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 194  : Actual Value  Keep right
# Predicted Value  Stop
# Wrong Prediction
#
# 195  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 196  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 197  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 198  : Actual Value  Keep right
# Predicted Value  Speed limit (120km/h)
# Wrong Prediction
#
# 199  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 200  : Actual Value  Children crossing
# Predicted Value  Children crossing
# True Prediction
#
# 201  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 202  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 203  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 204  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 205  : Actual Value  No entry
# Predicted Value  Go straight or right
# Wrong Prediction
#
# 206  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 207  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 208  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 209  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 210  : Actual Value  No vehicles
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 211  : Actual Value  No vehicles
# Predicted Value  No vehicles
# True Prediction
#
# 212  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 213  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 214  : Actual Value  Speed limit (80km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 215  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 216  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 217  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 218  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 219  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 220  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 221  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 222  : Actual Value  Speed limit (70km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 223  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 224  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 225  : Actual Value  Stop
# Predicted Value  Turn right ahead
# Wrong Prediction
#
# 226  : Actual Value  Priority road
# Predicted Value  Ahead only
# Wrong Prediction
#
# 227  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 228  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 229  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 230  : Actual Value  Go straight or right
# Predicted Value  Go straight or right
# True Prediction
#
# 231  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 232  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 233  : Actual Value  Turn right ahead
# Predicted Value  No entry
# Wrong Prediction
#
# 234  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 235  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 236  : Actual Value  Dangerous curve left
# Predicted Value  Dangerous curve left
# True Prediction
#
# 237  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 238  : Actual Value  Beware of ice/snow
# Predicted Value  Beware of ice/snow
# True Prediction
#
# 239  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 240  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 241  : Actual Value  Priority road
# Predicted Value  Ahead only
# Wrong Prediction
#
# 242  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 243  : Actual Value  Dangerous curve right
# Predicted Value  Dangerous curve right
# True Prediction
#
# 244  : Actual Value  Speed limit (20km/h)
# Predicted Value  Speed limit (20km/h)
# True Prediction
#
# 245  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 246  : Actual Value  Roundabout mandatory
# Predicted Value  No entry
# Wrong Prediction
#
# 247  : Actual Value  Speed limit (80km/h)
# Predicted Value  Turn left ahead
# Wrong Prediction
#
# 248  : Actual Value  Speed limit (120km/h)
# Predicted Value  No passing
# Wrong Prediction
#
# 249  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 250  : Actual Value  Keep right
# Predicted Value  Turn left ahead
# Wrong Prediction
#
# 251  : Actual Value  Dangerous curve right
# Predicted Value  Dangerous curve right
# True Prediction
#
# 252  : Actual Value  Stop
# Predicted Value  Keep left
# Wrong Prediction
#
# 253  : Actual Value  Speed limit (20km/h)
# Predicted Value  Speed limit (20km/h)
# True Prediction
#
# 254  : Actual Value  Go straight or right
# Predicted Value  Go straight or right
# True Prediction
#
# 255  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 256  : Actual Value  Children crossing
# Predicted Value  Children crossing
# True Prediction
#
# 257  : Actual Value  Ahead only
# Predicted Value  Ahead only
# True Prediction
#
# 258  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 259  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 260  : Actual Value  No vehicles
# Predicted Value  No vehicles
# True Prediction
#
# 261  : Actual Value  Ahead only
# Predicted Value  Yield
# Wrong Prediction
#
# 262  : Actual Value  Stop
# Predicted Value  Stop
# True Prediction
#
# 263  : Actual Value  General caution
# Predicted Value  Traffic signals
# Wrong Prediction
#
# 264  : Actual Value  Road work
# Predicted Value  Slippery road
# Wrong Prediction
#
# 265  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 266  : Actual Value  Priority road
# Predicted Value  End speed + passing limits
# Wrong Prediction
#
# 267  : Actual Value  Speed limit (80km/h)
# Predicted Value  Turn left ahead
# Wrong Prediction
#
# 268  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 269  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 270  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 271  : Actual Value  General caution
# Predicted Value  Ahead only
# Wrong Prediction
#
# 272  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 273  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 274  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 275  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 276  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 277  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 278  : Actual Value  Keep left
# Predicted Value  No vehicles
# Wrong Prediction
#
# 279  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 280  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 281  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 282  : Actual Value  Ahead only
# Predicted Value  No passing
# Wrong Prediction
#
# 283  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 284  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 285  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 286  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 287  : Actual Value  Turn right ahead
# Predicted Value  Yield
# Wrong Prediction
#
# 288  : Actual Value  Beware of ice/snow
# Predicted Value  Double curve
# Wrong Prediction
#
# 289  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 290  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 291  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 292  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 293  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 294  : Actual Value  Ahead only
# Predicted Value  No passing
# Wrong Prediction
#
# 295  : Actual Value  Speed limit (80km/h)
# Predicted Value  Priority road
# Wrong Prediction
#
# 296  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 297  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 298  : Actual Value  Children crossing
# Predicted Value  Children crossing
# True Prediction
#
# 299  : Actual Value  Ahead only
# Predicted Value  Stop
# Wrong Prediction
#
# 300  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 301  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 302  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 303  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 304  : Actual Value  Stop
# Predicted Value  Stop
# True Prediction
#
# 305  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 306  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 307  : Actual Value  End speed + passing limits
# Predicted Value  End speed + passing limits
# True Prediction
#
# 308  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 309  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 310  : Actual Value  Keep right
# Predicted Value  Traffic signals
# Wrong Prediction
#
# 311  : Actual Value  Dangerous curve left
# Predicted Value  Dangerous curve left
# True Prediction
#
# 312  : Actual Value  Right-of-way at intersection
# Predicted Value  Ahead only
# Wrong Prediction
#
# 313  : Actual Value  Keep right
# Predicted Value  Stop
# Wrong Prediction
#
# 314  : Actual Value  Keep right
# Predicted Value  Road work
# Wrong Prediction
#
# 315  : Actual Value  Speed limit (30km/h)
# Predicted Value  Priority road
# Wrong Prediction
#
# 316  : Actual Value  End no passing veh > 3.5 tons
# Predicted Value  End no passing veh > 3.5 tons
# True Prediction
#
# 317  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 318  : Actual Value  Roundabout mandatory
# Predicted Value  No entry
# Wrong Prediction
#
# 319  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 320  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 321  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 322  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 323  : Actual Value  Speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# Wrong Prediction
#
# 324  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 325  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 326  : Actual Value  Ahead only
# Predicted Value  Ahead only
# True Prediction
#
# 327  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 328  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 329  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 330  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 331  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 332  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 333  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (50km/h)
# Wrong Prediction
#
# 334  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 335  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 336  : Actual Value  End of speed limit (80km/h)
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 337  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 338  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 339  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 340  : Actual Value  Bumpy road
# Predicted Value  Keep right
# Wrong Prediction
#
# 341  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 342  : Actual Value  Bicycles crossing
# Predicted Value  Slippery road
# Wrong Prediction
#
# 343  : Actual Value  No passing
# Predicted Value  Ahead only
# Wrong Prediction
#
# 344  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 345  : Actual Value  Keep right
# Predicted Value  Children crossing
# Wrong Prediction
#
# 346  : Actual Value  Keep right
# Predicted Value  Road work
# Wrong Prediction
#
# 347  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 348  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 349  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 350  : Actual Value  Children crossing
# Predicted Value  Children crossing
# True Prediction
#
# 351  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 352  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 353  : Actual Value  Veh > 3.5 tons prohibited
# Predicted Value  Veh > 3.5 tons prohibited
# True Prediction
#
# 354  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 355  : Actual Value  Priority road
# Predicted Value  Ahead only
# Wrong Prediction
#
# 356  : Actual Value  Roundabout mandatory
# Predicted Value  Stop
# Wrong Prediction
#
# 357  : Actual Value  Ahead only
# Predicted Value  Children crossing
# Wrong Prediction
#
# 358  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 359  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 360  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 361  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 362  : Actual Value  Keep right
# Predicted Value  Yield
# Wrong Prediction
#
# 363  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 364  : Actual Value  Keep left
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 365  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 366  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 367  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 368  : Actual Value  Keep right
# Predicted Value  Yield
# Wrong Prediction
#
# 369  : Actual Value  Dangerous curve left
# Predicted Value  Slippery road
# Wrong Prediction
#
# 370  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 371  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 372  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 373  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 374  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 375  : Actual Value  Traffic signals
# Predicted Value  Go straight or right
# Wrong Prediction
#
# 376  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 377  : Actual Value  End of no passing
# Predicted Value  End of no passing
# True Prediction
#
# 378  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 379  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 380  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 381  : Actual Value  Dangerous curve left
# Predicted Value  Dangerous curve left
# True Prediction
#
# 382  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 383  : Actual Value  Keep right
# Predicted Value  Road work
# Wrong Prediction
#
# 384  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 385  : Actual Value  Ahead only
# Predicted Value  No passing
# Wrong Prediction
#
# 386  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 387  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 388  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 389  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 390  : Actual Value  No passing
# Predicted Value  Ahead only
# Wrong Prediction
#
# 391  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 392  : Actual Value  Turn right ahead
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 393  : Actual Value  Children crossing
# Predicted Value  Children crossing
# True Prediction
#
# 394  : Actual Value  Speed limit (50km/h)
# Predicted Value  Go straight or left
# Wrong Prediction
#
# 395  : Actual Value  Speed limit (30km/h)
# Predicted Value  End speed + passing limits
# Wrong Prediction
#
# 396  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (100km/h)
# Wrong Prediction
#
# 397  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 398  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 399  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 400  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 401  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 402  : Actual Value  Go straight or right
# Predicted Value  Go straight or right
# True Prediction
#
# 403  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 404  : Actual Value  Speed limit (20km/h)
# Predicted Value  Speed limit (20km/h)
# True Prediction
#
# 405  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 406  : Actual Value  Go straight or right
# Predicted Value  Children crossing
# Wrong Prediction
#
# 407  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 408  : Actual Value  Road work
# Predicted Value  Ahead only
# Wrong Prediction
#
# 409  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 410  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 411  : Actual Value  Road work
# Predicted Value  Right-of-way at intersection
# Wrong Prediction
#
# 412  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 413  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 414  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 415  : Actual Value  Bicycles crossing
# Predicted Value  Slippery road
# Wrong Prediction
#
# 416  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 417  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 418  : Actual Value  Stop
# Predicted Value  Turn left ahead
# Wrong Prediction
#
# 419  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 420  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 421  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 422  : Actual Value  Speed limit (70km/h)
# Predicted Value  End of speed limit (80km/h)
# Wrong Prediction
#
# 423  : Actual Value  Dangerous curve left
# Predicted Value  Dangerous curve left
# True Prediction
#
# 424  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 425  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 426  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 427  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 428  : Actual Value  Dangerous curve right
# Predicted Value  Dangerous curve right
# True Prediction
#
# 429  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 430  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 431  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 432  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 433  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 434  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 435  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 436  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 437  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 438  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 439  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 440  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 441  : Actual Value  Bumpy road
# Predicted Value  Bumpy road
# True Prediction
#
# 442  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 443  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 444  : Actual Value  Beware of ice/snow
# Predicted Value  Slippery road
# Wrong Prediction
#
# 445  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 446  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 447  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 448  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 449  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 450  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (100km/h)
# Wrong Prediction
#
# 451  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 452  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 453  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 454  : Actual Value  Roundabout mandatory
# Predicted Value  No entry
# Wrong Prediction
#
# 455  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 456  : Actual Value  Keep right
# Predicted Value  Right-of-way at intersection
# Wrong Prediction
#
# 457  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 458  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 459  : Actual Value  Keep left
# Predicted Value  Stop
# Wrong Prediction
#
# 460  : Actual Value  End of speed limit (80km/h)
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 461  : Actual Value  Ahead only
# Predicted Value  No passing
# Wrong Prediction
#
# 462  : Actual Value  Road work
# Predicted Value  Right-of-way at intersection
# Wrong Prediction
#
# 463  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 464  : Actual Value  No entry
# Predicted Value  Keep right
# Wrong Prediction
#
# 465  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 466  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 467  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 468  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 469  : Actual Value  Stop
# Predicted Value  Turn right ahead
# Wrong Prediction
#
# 470  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 471  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (100km/h)
# Wrong Prediction
#
# 472  : Actual Value  Ahead only
# Predicted Value  Children crossing
# Wrong Prediction
#
# 473  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (50km/h)
# Wrong Prediction
#
# 474  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 475  : Actual Value  Ahead only
# Predicted Value  Yield
# Wrong Prediction
#
# 476  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 477  : Actual Value  Ahead only
# Predicted Value  Children crossing
# Wrong Prediction
#
# 478  : Actual Value  Go straight or right
# Predicted Value  Dangerous curve right
# Wrong Prediction
#
# 479  : Actual Value  Road narrows on the right
# Predicted Value  Road narrows on the right
# True Prediction
#
# 480  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 481  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 482  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 483  : Actual Value  Ahead only
# Predicted Value  Ahead only
# True Prediction
#
# 484  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 485  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 486  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 487  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 488  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 489  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 490  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 491  : Actual Value  No entry
# Predicted Value  End speed + passing limits
# Wrong Prediction
#
# 492  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 493  : Actual Value  Speed limit (70km/h)
# Predicted Value  Priority road
# Wrong Prediction
#
# 494  : Actual Value  Speed limit (60km/h)
# Predicted Value  End of speed limit (80km/h)
# Wrong Prediction
#
# 495  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 496  : Actual Value  Speed limit (80km/h)
# Predicted Value  Turn left ahead
# Wrong Prediction
#
# 497  : Actual Value  Beware of ice/snow
# Predicted Value  Beware of ice/snow
# True Prediction
#
# 498  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 499  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 500  : Actual Value  Roundabout mandatory
# Predicted Value  Priority road
# Wrong Prediction
#
# 501  : Actual Value  Bumpy road
# Predicted Value  Slippery road
# Wrong Prediction
#
# 502  : Actual Value  Beware of ice/snow
# Predicted Value  Slippery road
# Wrong Prediction
#
# 503  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 504  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 505  : Actual Value  Slippery road
# Predicted Value  Slippery road
# True Prediction
#
# 506  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 507  : Actual Value  End speed + passing limits
# Predicted Value  End speed + passing limits
# True Prediction
#
# 508  : Actual Value  End no passing veh > 3.5 tons
# Predicted Value  End no passing veh > 3.5 tons
# True Prediction
#
# 509  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 510  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 511  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 512  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 513  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 514  : Actual Value  Bumpy road
# Predicted Value  Keep right
# Wrong Prediction
#
# 515  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 516  : Actual Value  Turn right ahead
# Predicted Value  No entry
# Wrong Prediction
#
# 517  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 518  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 519  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 520  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 521  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 522  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 523  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 524  : Actual Value  Stop
# Predicted Value  Turn left ahead
# Wrong Prediction
#
# 525  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 526  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 527  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 528  : Actual Value  Speed limit (80km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 529  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 530  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 531  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 532  : Actual Value  No vehicles
# Predicted Value  No vehicles
# True Prediction
#
# 533  : Actual Value  Slippery road
# ...
# True Prediction
#
# 12460  : Actual Value  Double curve
# Predicted Value  Double curve
# True Prediction
#
# 12461  : Actual Value  Stop
# Predicted Value  Turn right ahead
# Wrong Prediction
#
# 12462  : Actual Value  Priority road
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12463  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 12464  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12465  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (100km/h)
# Wrong Prediction
#
# 12466  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 12467  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12468  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 12469  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12470  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 12471  : Actual Value  Bicycles crossing
# Predicted Value  Bicycles crossing
# True Prediction
#
# 12472  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 12473  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12474  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 12475  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (80km/h)
# Wrong Prediction
#
# 12476  : Actual Value  Roundabout mandatory
# Predicted Value  Priority road
# Wrong Prediction
#
# 12477  : Actual Value  Beware of ice/snow
# Predicted Value  Road work
# Wrong Prediction
#
# 12478  : Actual Value  Speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# Wrong Prediction
#
# 12479  : Actual Value  Dangerous curve left
# Predicted Value  Dangerous curve left
# True Prediction
#
# 12480  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12481  : Actual Value  Keep right
# Predicted Value  Stop
# Wrong Prediction
#
# 12482  : Actual Value  Speed limit (80km/h)
# Predicted Value  Priority road
# Wrong Prediction
#
# 12483  : Actual Value  Speed limit (50km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12484  : Actual Value  Ahead only
# Predicted Value  Stop
# Wrong Prediction
#
# 12485  : Actual Value  Speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# Wrong Prediction
#
# 12486  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12487  : Actual Value  No entry
# Predicted Value  No entry
# True Prediction
#
# 12488  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 12489  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 12490  : Actual Value  Speed limit (70km/h)
# Predicted Value  Keep left
# Wrong Prediction
#
# 12491  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 12492  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12493  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 12494  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 12495  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 12496  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 12497  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 12498  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 12499  : Actual Value  End speed + passing limits
# Predicted Value  End speed + passing limits
# True Prediction
#
# 12500  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12501  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 12502  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 12503  : Actual Value  End no passing veh > 3.5 tons
# Predicted Value  End no passing veh > 3.5 tons
# True Prediction
#
# 12504  : Actual Value  Road work
# Predicted Value  Slippery road
# Wrong Prediction
#
# 12505  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 12506  : Actual Value  Stop
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12507  : Actual Value  Turn left ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 12508  : Actual Value  Traffic signals
# Predicted Value  Traffic signals
# True Prediction
#
# 12509  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12510  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 12511  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 12512  : Actual Value  Turn right ahead
# Predicted Value  No entry
# Wrong Prediction
#
# 12513  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12514  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12515  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12516  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12517  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12518  : Actual Value  No vehicles
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12519  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 12520  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12521  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12522  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 12523  : Actual Value  General caution
# Predicted Value  Traffic signals
# Wrong Prediction
#
# 12524  : Actual Value  Speed limit (70km/h)
# Predicted Value  Speed limit (70km/h)
# True Prediction
#
# 12525  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 12526  : Actual Value  Dangerous curve right
# Predicted Value  Dangerous curve right
# True Prediction
#
# 12527  : Actual Value  Speed limit (60km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12528  : Actual Value  No vehicles
# Predicted Value  No vehicles
# True Prediction
#
# 12529  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 12530  : Actual Value  Keep right
# Predicted Value  Stop
# Wrong Prediction
#
# 12531  : Actual Value  Speed limit (50km/h)
# Predicted Value  Turn right ahead
# Wrong Prediction
#
# 12532  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 12533  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12534  : Actual Value  Stop
# Predicted Value  Keep right
# Wrong Prediction
#
# 12535  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12536  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12537  : Actual Value  Road work
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12538  : Actual Value  Children crossing
# Predicted Value  Children crossing
# True Prediction
#
# 12539  : Actual Value  Road narrows on the right
# Predicted Value  Road narrows on the right
# True Prediction
#
# 12540  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 12541  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 12542  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 12543  : Actual Value  Speed limit (70km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12544  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12545  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 12546  : Actual Value  Keep right
# Predicted Value  No entry
# Wrong Prediction
#
# 12547  : Actual Value  Road narrows on the right
# Predicted Value  Road narrows on the right
# True Prediction
#
# 12548  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 12549  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 12550  : Actual Value  Speed limit (80km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12551  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12552  : Actual Value  Bumpy road
# Predicted Value  Slippery road
# Wrong Prediction
#
# 12553  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 12554  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 12555  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 12556  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 12557  : Actual Value  Veh > 3.5 tons prohibited
# Predicted Value  Veh > 3.5 tons prohibited
# True Prediction
#
# 12558  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (50km/h)
# Wrong Prediction
#
# 12559  : Actual Value  Ahead only
# Predicted Value  No passing
# Wrong Prediction
#
# 12560  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12561  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 12562  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 12563  : Actual Value  Speed limit (120km/h)
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 12564  : Actual Value  Beware of ice/snow
# Predicted Value  Beware of ice/snow
# True Prediction
#
# 12565  : Actual Value  Slippery road
# Predicted Value  Slippery road
# True Prediction
#
# 12566  : Actual Value  Speed limit (50km/h)
# Predicted Value  Go straight or left
# Wrong Prediction
#
# 12567  : Actual Value  Keep left
# Predicted Value  Stop
# Wrong Prediction
#
# 12568  : Actual Value  Slippery road
# Predicted Value  Slippery road
# True Prediction
#
# 12569  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12570  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 12571  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12572  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 12573  : Actual Value  No vehicles
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 12574  : Actual Value  No entry
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 12575  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 12576  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 12577  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 12578  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 12579  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 12580  : Actual Value  Dangerous curve right
# Predicted Value  Dangerous curve right
# True Prediction
#
# 12581  : Actual Value  Speed limit (50km/h)
# Predicted Value  Speed limit (50km/h)
# True Prediction
#
# 12582  : Actual Value  No passing
# Predicted Value  No passing
# True Prediction
#
# 12583  : Actual Value  Speed limit (60km/h)
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12584  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12585  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 12586  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 12587  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12588  : Actual Value  End of speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# True Prediction
#
# 12589  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12590  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12591  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 12592  : Actual Value  Speed limit (80km/h)
# Predicted Value  End of speed limit (80km/h)
# Wrong Prediction
#
# 12593  : Actual Value  Bumpy road
# Predicted Value  Bumpy road
# True Prediction
#
# 12594  : Actual Value  Speed limit (60km/h)
# Predicted Value  Speed limit (60km/h)
# True Prediction
#
# 12595  : Actual Value  Priority road
# Predicted Value  End speed + passing limits
# Wrong Prediction
#
# 12596  : Actual Value  Road work
# Predicted Value  Road work
# True Prediction
#
# 12597  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12598  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12599  : Actual Value  Ahead only
# Predicted Value  No passing
# Wrong Prediction
#
# 12600  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12601  : Actual Value  Ahead only
# Predicted Value  No passing
# Wrong Prediction
#
# 12602  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 12603  : Actual Value  Road narrows on the right
# Predicted Value  Road narrows on the right
# True Prediction
#
# 12604  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12605  : Actual Value  Ahead only
# Predicted Value  Stop
# Wrong Prediction
#
# 12606  : Actual Value  Road work
# Predicted Value  Right-of-way at intersection
# Wrong Prediction
#
# 12607  : Actual Value  Keep right
# Predicted Value  Keep right
# True Prediction
#
# 12608  : Actual Value  Speed limit (30km/h)
# Predicted Value  Speed limit (30km/h)
# True Prediction
#
# 12609  : Actual Value  General caution
# Predicted Value  Ahead only
# Wrong Prediction
#
# 12610  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 12611  : Actual Value  Ahead only
# Predicted Value  Stop
# Wrong Prediction
#
# 12612  : Actual Value  Right-of-way at intersection
# Predicted Value  Right-of-way at intersection
# True Prediction
#
# 12613  : Actual Value  Keep left
# Predicted Value  Stop
# Wrong Prediction
#
# 12614  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 12615  : Actual Value  Speed limit (20km/h)
# Predicted Value  Speed limit (20km/h)
# True Prediction
#
# 12616  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  No passing veh over 3.5 tons
# True Prediction
#
# 12617  : Actual Value  General caution
# Predicted Value  General caution
# True Prediction
#
# 12618  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 12619  : Actual Value  Speed limit (120km/h)
# Predicted Value  Speed limit (120km/h)
# True Prediction
#
# 12620  : Actual Value  Wild animals crossing
# Predicted Value  Wild animals crossing
# True Prediction
#
# 12621  : Actual Value  Yield
# Predicted Value  Yield
# True Prediction
#
# 12622  : Actual Value  Speed limit (80km/h)
# Predicted Value  Speed limit (80km/h)
# True Prediction
#
# 12623  : Actual Value  Priority road
# Predicted Value  Roundabout mandatory
# Wrong Prediction
#
# 12624  : Actual Value  Ahead only
# Predicted Value  Stop
# Wrong Prediction
#
# 12625  : Actual Value  Road work
# Predicted Value  Right-of-way at intersection
# Wrong Prediction
#
# 12626  : Actual Value  Priority road
# Predicted Value  Priority road
# True Prediction
#
# 12627  : Actual Value  Turn right ahead
# Predicted Value  Stop
# Wrong Prediction
#
# 12628  : Actual Value  End of speed limit (80km/h)
# Predicted Value  Speed limit (30km/h)
# Wrong Prediction
#
# 12629  : Actual Value  Speed limit (100km/h)
# Predicted Value  Speed limit (100km/h)
# True Prediction
#
# 12630  : Actual Value  No passing veh over 3.5 tons
# Predicted Value  Speed limit (50km/h)
# Wrong Prediction

# %%
false_count
# Out:
# 3675

# %%
true_count
# Out:
# 8955

# %%
accuracy = true_count / (true_count + false_count)

print(f'Accuracy on test data: {accuracy * 100}%')
# Out:
# Accuracy on test data: 70.90261282660333%
